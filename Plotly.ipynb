970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982]

# %%
trace_1 = go.Scatter(x = df.model_year, y = df.horsepower,
                     name = 'horsepower',
                     mode = 'markers',
                     marker = dict(size = 10,
                                   color = 'rgba(229, 151, 50, .6)'))
                     
trace_2 = go.Scatter(x = df.model_year, y = df.displacement,
                     name = 'displacement',
                     mode = 'markers',
                     marker = dict(size = 10,
                                   color = 'rgba(106, 181, 135, .6)'))
                     
layout = go.Layout(title = 'MPG Scatter Plot',
                   hovermode = 'closest')
                     
fig = go.Figure(data = [trace_1, trace_2], layout = layout)
                     
iplot(fig)
# Out:
# <div id="97578b4a-eeb0-46ac-b84b-bbc9b394166a" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("97578b4a-eeb0-46ac-b84b-bbc9b394166a", [{"marker": {"color": "rgba(229, 151, 50, .6)", "size": 10}, "mode": "markers", "name": "horsepower", "x": [1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970, 1971, 1971, 1971, 1971, 1971, 1971, 1971, 1971, 1971, 1971, 1971, 1971, 1971, 1971, 1971, 1971, 1971, 1971, 1971, 1971, 1971, 1971, 1971, 1971, 1971, 1971, 1971, 1971, 1972, 1972, 1972, 1972, 1972, 1972, 1972, 1972, 1972, 1972, 1972, 1972, 1972, 1972, 1972, 1972, 1972, 1972, 1972, 1972, 1972, 1972, 1972, 1972, 1972, 1972, 1972, 1972, 1973, 1973, 1973, 1973, 1973, 1973, 1973, 1973, 1973, 1973, 1973, 1973, 1973, 1973, 1973, 1973, 1973, 1973, 1973, 1973, 1973, 1973, 1973, 1973, 1973, 1973, 1973, 1973, 1973, 1973, 1973, 1973, 1973, 1973, 1973, 1973, 1973, 1973, 1973, 1973, 1974, 1974, 1974, 1974, 1974, 1974, 1974, 1974, 1974, 1974, 1974, 1974, 1974, 1974, 1974, 1974, 1974, 1974, 1974, 1974, 1974, 1974, 1974, 1974, 1974, 1974, 1974, 1975, 1975, 1975, 1975, 1975, 1975, 1975, 1975, 1975, 1975, 1975, 1975, 1975, 1975, 1975, 1975, 1975, 1975, 1975, 1975, 1975, 1975, 1975, 1975, 1975, 1975, 1975, 1975, 1975, 1975, 1976, 1976, 1976, 1976, 1976, 1976, 1976, 1976, 1976, 1976, 1976, 1976, 1976, 1976, 1976, 1976, 1976, 1976, 1976, 1976, 1976, 1976, 1976, 1976, 1976, 1976, 1976, 1976, 1976, 1976, 1976, 1976, 1976, 1976, 1977, 1977, 1977, 1977, 1977, 1977, 1977, 1977, 1977, 1977, 1977, 1977, 1977, 1977, 1977, 1977, 1977, 1977, 1977, 1977, 1977, 1977, 1977, 1977, 1977, 1977, 1977, 1977, 1978, 1978, 1978, 1978, 1978, 1978, 1978, 1978, 1978, 1978, 1978, 1978, 1978, 1978, 1978, 1978, 1978, 1978, 1978, 1978, 1978, 1978, 1978, 1978, 1978, 1978, 1978, 1978, 1978, 1978, 1978, 1978, 1978, 1978, 1978, 1978, 1979, 1979, 1979, 1979, 1979, 1979, 1979, 1979, 1979, 1979, 1979, 1979, 1979, 1979, 1979, 1979, 1979, 1979, 1979, 1979, 1979, 1979, 1979, 1979, 1979, 1979, 1979, 1979, 1979, 1980, 1980, 1980, 1980, 1980, 1980, 1980, 1980, 1980, 1980, 1980, 1980, 1980, 1980, 1980, 1980, 1980, 1980, 1980, 1980, 1980, 1980, 1980, 1980, 1980, 1980, 1980, 1980, 1980, 1981, 1981, 1981, 1981, 1981, 1981, 1981, 1981, 1981, 1981, 1981, 1981, 1981, 1981, 1981, 1981, 1981, 1981, 1981, 1981, 1981, 1981, 1981, 1981, 1981, 1981, 1981, 1981, 1981, 1982, 1982, 1982, 1982, 1982, 1982, 1982, 1982, 1982, 1982, 1982, 1982, 1982, 1982, 1982, 1982, 1982, 1982, 1982, 1982, 1982, 1982, 1982, 1982, 1982, 1982, 1982, 1982, 1982, 1982, 1982], "y": ["130", "165", "150", "150", "140", "198", "220", "215", "225", "190", "170", "160", "150", "225", "95", "95", "97", "85", "88", "46", "87", "90", "95", "113", "90", "215", "200", "210", "193", "88", "90", "95", "?", "100", "105", "100", "88", "100", "165", "175", "153", "150", "180", "170", "175", "110", "72", "100", "88", "86", "90", "70", "76", "65", "69", "60", "70", "95", "80", "54", "90", "86", "165", "175", "150", "153", "150", "208", "155", "160", "190", "97", "150", "130", "140", "150", "112", "76", "87", "69", "86", "92", "97", "80", "88", "175", "150", "145", "137", "150", "198", "150", "158", "150", "215", "225", "175", "105", "100", "100", "88", "95", "46", "150", "167", "170", "180", "100", "88", "72", "94", "90", "85", "107", "90", "145", "230", "49", "75", "91", "112", "150", "110", "122", "180", "95", "?", "100", "100", "67", "80", "65", "75", "100", "110", "105", "140", "150", "150", "140", "150", "83", "67", "78", "52", "61", "75", "75", "75", "97", "93", "67", "95", "105", "72", "72", "170", "145", "150", "148", "110", "105", "110", "95", "110", "110", "129", "75", "83", "100", "78", "96", "71", "97", "97", "70", "90", "95", "88", "98",  ...

# %% [markdown]
# # Line plot

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Pierian-Data/Plotly-Dashboards-with-Dash/master/Data/2010YumaAZ.csv')
df.head()
# Out:
#    LST_DATE      DAY LST_TIME  T_HR_AVG
# 0  20100601  TUESDAY     0:00      25.2
# 1  20100601  TUESDAY     1:00      24.1
# 2  20100601  TUESDAY     2:00      24.4
# 3  20100601  TUESDAY     3:00      24.9
# 4  20100601  TUESDAY     4:00      22.8

# %%
days = df.DAY.unique()
days
# Out:
# array(['TUESDAY', 'WEDNESDAY', 'THURSDAY', 'FRIDAY', 'SATURDAY', 'SUNDAY',
#        'MONDAY'], dtype=object)

# %%
data = []
for day in days:
    trace = go.Scatter(x = df[df.DAY == day]['LST_TIME'], 
                       y = df[df.DAY == day]['T_HR_AVG'], 
                       name = day,
                       mode = 'lines',
                       line = dict(width = 2, 
                                   dash = 'dash'))
    data.append(trace)

layout = go.Layout(title = "Day Temperature Plot",
                  hovermode = 'closest')

fig = go.Figure(data = data, layout = layout)

iplot(fig)
# Out:
# <div id="08a539a2-7178-472b-a279-4b18f464c88b" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("08a539a2-7178-472b-a279-4b18f464c88b", [{"line": {"dash": "dash", "width": 2}, "mode": "lines", "name": "TUESDAY", "x": ["0:00", "1:00", "2:00", "3:00", "4:00", "5:00", "6:00", "7:00", "8:00", "9:00", "10:00", "11:00", "12:00", "13:00", "14:00", "15:00", "16:00", "17:00", "18:00", "19:00", "20:00", "21:00", "22:00", "23:00"], "y": [25.2, 24.1, 24.4, 24.9, 22.8, 19.8, 18.8, 21.2, 24.2, 27.1, 29.3, 30.6, 32.6, 34.0, 34.0, 34.9, 34.6, 33.8, 33.5, 32.8, 31.0, 29.0, 27.6, 26.3], "type": "scatter", "uid": "820d8196-45f6-4ce2-ad97-b91a7dcde3ec"}, {"line": {"dash": "dash", "width": 2}, "mode": "lines", "name": "WEDNESDAY", "x": ["0:00", "1:00", "2:00", "3:00", "4:00", "5:00", "6:00", "7:00", "8:00", "9:00", "10:00", "11:00", "12:00", "13:00", "14:00", "15:00", "16:00", "17:00", "18:00", "19:00", "20:00", "21:00", "22:00", "23:00"], "y": [23.8, 20.6, 19.1, 18.4, 18.9, 18.2, 17.9, 20.2, 23.8, 26.1, 27.9, 29.3, 30.9, 32.2, 33.1, 33.7, 34.5, 34.7, 34.8, 34.2, 32.8, 31.0, 28.7, 25.5], "type": "scatter", "uid": "e940769d-3ce9-4070-9337-ab8b42400f4f"}, {"line": {"dash": "dash", "width": 2}, "mode": "lines", "name": "THURSDAY", "x": ["0:00", "1:00", "2:00", "3:00", "4:00", "5:00", "6:00", "7:00", "8:00", "9:00", "10:00", "11:00", "12:00", "13:00", "14:00", "15:00", "16:00", "17:00", "18:00", "19:00", "20:00", "21:00", "22:00", "23:00"], "y": [24.3, 23.1, 21.8, 19.8, 18.5, 19.2, 19.7, 20.7, 23.2, 26.1, 28.6, 30.8, 32.3, 33.8, 34.9, 35.8, 35.9, 36.3, 35.8, 35.4, 34.2, 32.7, 31.1, 28.6], "type": "scatter", "uid": "c59bf93c-71a8-4a09-b6e3-baae4500eb1f"}, {"line": {"dash": "dash", "width": 2}, "mode": "lines", "name": "FRIDAY", "x": ["0:00", "1:00", "2:00", "3:00", "4:00", "5:00", "6:00", "7:00", "8:00", "9:00", "10:00", "11:00", "12:00", "13:00", "14:00", "15:00", "16:00", "17:00", "18:00", "19:00", "20:00", "21:00", "22:00", "23:00"], "y": [26.4, 25.4, 24.2, 23.6, 22.5, 21.0, 21.3, 22.5, 24.7, 28.1, 30.6, 32.5, 33.9, 35.5, 36.6, 37.2, 37.8, 38.1, 38.2, 37.4, 36.0, 34.4, 32.6, 30.1], "type": "scatter", "uid": "c28b453e-761b-4011-b9ba-aee38528107c"}, {"line": {"dash": "dash", "width": 2}, "mode": "lines", "name": "SATURDAY", "x": ["0:00", "1:00", "2:00", "3:00", "4:00", "5:00", "6:00", "7:00", "8:00", "9:00", "10:00", "11:00", "12:00", "13:00", "14:00", "15:00", "16:00", "17:00", "18:00", "19:00", "20:00", "21:00", "22:00", "23:00"], "y": [28.3, 27.3, 26.3, 25.3, 24.7, 24.7, 23.9, 24.7, 27.7, 30.4, 32.6, 34.8, 36.4, 37.2, 38.4, 39.7, 40.0, 40.4, 40.1, 39.0, 37.3, 35.7, 33.9, 31.4], "type": "scatter", "uid": "51ee0edf-272c-4b89-a2a0-aa6e7aef6d98"}, {"line": {"dash": "dash", "width": 2}, "mode": "lines", "name": "SUNDAY", "x": ["0:00", "1:00", "2:00", "3:00", "4:00", "5:00", "6:00", "7:00", "8:00", "9:00", "10:00", "11:00", "12:00", "13:00", "14:00", "15:00", "16:00", "17:00", "18:00", "19:00", "20:00", "21:00", "22:00", "23:00"], "y": [29.7, 28.6, 26.9, 25.9, 25.2, 24.8, 23.9, 26.1, 27.9, 30.5, 33.7, 35.6, 36.9, 38.4, 39.2, 40.2, 40.6, 40.6, 40.3, 39.5, 37.9, 36.5, 35.0, 32.9], "type": "scatter", "uid": "2092884d-5e20-470d-ba7a-11cf3751141f"}, {"line": {"dash": "dash", "width": 2}, "mode": "lines", "name": "MONDAY", "x": ["0:00", "1:00", "2:00", "3:00", "4:00", "5:00", "6:00", "7:00", "8:00", "9:00", "10:00", "11:00", "12:00", "13:00", "14:00", "15:00", "16:00", "17:00", "18:00", "19:00", "20:00", "21:00", "22:00", "23:00"], "y": [30.9, 28.7, 26.9, 25.2, 24.1, 24.3, 23.4, 25.7, 28.5, 30.7, 32.5, 34.1, 36.1, 37.6, 39.0, 40.2, 40.3, 40.2, 40.1, 39.4, 38.5, 37.0, 34.7, 32.6], "type": "scatter", "uid": "de428a6f-a30b-4a80-9a50-ad5e1cf8791e"}], {"hovermode": "closest", "title": "Day Temperature Plot"}, {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "h ...

# %% [markdown]
# # Bar plot

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Pierian-Data/Plotly-Dashboards-with-Dash/master/Data/mocksurvey.csv')
df.head()
# Out:
#    Unnamed: 0  Strongly Agree  Somewhat Agree  Neutral  Somewhat Disagree  \
# 0  Question 1            0.45            0.25     0.10               0.12
# 1  Question 2            0.12            0.07     0.48               0.18
# 2  Question 3            0.05            0.22     0.19               0.23
#
#    Strongly Disagree
# 0               0.08
# 1               0.15
# 2               0.31

# %%
features = df.iloc[:, 1:].columns

# %%
data = []
for i in features:
    trace = go.Bar(y = df['Unnamed: 0'], x = df[i], 
                   name = i,
                  orientation = 'h')
    data.append(trace)

layout = go.Layout(title = 'Mock Survey', 
                  barmode = 'stack')

fig = go.Figure(data, layout)
iplot(fig)
# Out:
# <div id="91598eae-ce18-4a62-b1dc-82e857613bc2" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("91598eae-ce18-4a62-b1dc-82e857613bc2", [{"name": "Strongly Agree", "orientation": "h", "x": [0.45, 0.12, 0.05], "y": ["Question 1", "Question 2", "Question 3"], "type": "bar", "uid": "7b3b0741-724f-4d07-b730-fff9c87a4270"}, {"name": "Somewhat Agree", "orientation": "h", "x": [0.25, 0.07, 0.22], "y": ["Question 1", "Question 2", "Question 3"], "type": "bar", "uid": "aee7e610-d6fc-4f03-89f3-17bbab6dbf6a"}, {"name": "Neutral", "orientation": "h", "x": [0.1, 0.48, 0.19], "y": ["Question 1", "Question 2", "Question 3"], "type": "bar", "uid": "768036fa-55df-4229-88cb-593a77e2f5d0"}, {"name": "Somewhat Disagree", "orientation": "h", "x": [0.12, 0.18, 0.23], "y": ["Question 1", "Question 2", "Question 3"], "type": "bar", "uid": "a9f27fff-cc83-4f19-a5bf-2eded0427f90"}, {"name": "Strongly Disagree", "orientation": "h", "x": [0.08, 0.15, 0.31], "y": ["Question 1", "Question 2", "Question 3"], "type": "bar", "uid": "341825e9-7784-4905-a83d-2db061d6930d"}], {"barmode": "stack", "title": "Mock Survey"}, {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("91598eae-ce18-4a62-b1dc-82e857613bc2"));});</script>

# %% [markdown]
# # Box Plot

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Pierian-Data/Plotly-Dashboards-with-Dash/master/Data/abalone.csv')
df.head()
# Out:
#   sex  length  diameter  height  whole_weight  shucked_weight  viscera_weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    shell_weight  rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
a = np.random.choice(df.rings, 40, replace = False)
b = np.random.choice(df.rings, 50, replace = False)

# %%
data = [go.Box(y = a, name = 'A'),
        go.Box(y = b, name = 'B')]
iplot(go.Figure(data))
# Out:
# <div id="d35420f6-bde2-45c0-bcfd-2229194d20b4" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("d35420f6-bde2-45c0-bcfd-2229194d20b4", [{"name": "A", "y": [8, 6, 10, 8, 10, 8, 13, 11, 11, 4, 12, 7, 10, 10, 12, 10, 4, 8, 11, 10, 17, 3, 12, 10, 8, 9, 8, 6, 15, 10, 9, 11, 10, 23, 21, 8, 15, 10, 7, 10], "type": "box", "uid": "183e8345-e183-4806-9d64-817d6eedb12f"}, {"name": "B", "y": [9, 5, 5, 3, 11, 12, 11, 9, 12, 10, 12, 5, 8, 8, 11, 4, 14, 7, 10, 7, 18, 14, 11, 8, 5, 8, 11, 15, 13, 9, 9, 10, 12, 11, 7, 6, 12, 8, 8, 21, 13, 9, 13, 10, 10, 11, 9, 9, 10, 10], "type": "box", "uid": "d0130aaa-ccf6-4497-b749-99b5a5dfe7cd"}], {}, {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("d35420f6-bde2-45c0-bcfd-2229194d20b4"));});</script>

# %% [markdown]
# # Histogram

# %%
x1 = np.random.randn(200) - 2
x2 = np.random.randn(200)
x3 = np.random.randn(200) + 2

# %%
hist_data = [x1, x2, x3]
group_labels = ['X1', 'X2', 'X3']

# %%
fig = ff.create_distplot(hist_data, group_labels, 
                        bin_size = [.1, .3, .2])
iplot(fig)
# Out:
# <div id="c8e78a60-8fcb-4a34-a1f1-044b6e083ff7" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("c8e78a60-8fcb-4a34-a1f1-044b6e083ff7", [{"autobinx": false, "histnorm": "probability density", "legendgroup": "X1", "marker": {"color": "rgb(31, 119, 180)"}, "name": "X1", "opacity": 0.7, "x": [-3.728008614824515, -2.0469719710901573, -0.8177174298842762, -2.237081610522291, -0.20599937941530966, -2.1168507594147363, -1.2917347665772174, -2.7513079879157507, -2.0473898123052
# %%
df = pd.read_csv('https://raw.githubusercontent.com/Pierian-Data/Plotly-Dashboards-with-Dash/master/Data/2010SantaBarbaraCA.csv')
df.head()
# Out:
#    LST_DATE      DAY LST_TIME  T_HR_AVG
# 0  20100601  TUESDAY     0:00      12.7
# 1  20100601  TUESDAY     1:00      12.7
# 2  20100601  TUESDAY     2:00      12.3
# 3  20100601  TUESDAY     3:00      12.5
# 4  20100601  TUESDAY     4:00      12.7

# %%
data = [go.Heatmap(x = df.DAY, y = df.LST_TIME,
                  z = df.T_HR_AVG.values.tolist())]
layout = go.Layout(title = 'SB CA Temps')
fig = go.Figure(data, layout)
iplot(fig)
# Out:
# <div id="21d2de27-cf27-44ff-abaa-bd01e2d68976" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("21d2de27-cf27-44ff-abaa-bd01e2d68976", [{"x": ["TUESDAY", "TUESDAY", "TUESDAY", "TUESDAY", "TUESDAY", "TUESDAY", "TUESDAY", "TUESDAY", "TUESDAY", "TUESDAY", "TUESDAY", "TUESDAY", "TUESDAY", "TUESDAY", "TUESDAY", "TUESDAY", "TUESDAY", "TUESDAY", "TUESDAY", "TUESDAY", "TUESDAY", "TUESDAY", "TUESDAY", "TUESDAY", "WEDNESDAY", "WEDNESDAY", "WEDNESDAY", "WEDNESDAY", "WEDNESDAY", "WEDNESDAY", "WEDNESDAY", "WEDNESDAY", "WEDNESDAY", "WEDNESDAY", "WEDNESDAY", "WEDNESDAY", "WEDNESDAY", "WEDNESDAY", "WEDNESDAY", "WEDNESDAY", "WEDNESDAY", "WEDNESDAY", "WEDNESDAY", "WEDNESDAY", "WEDNESDAY", "WEDNESDAY", "WEDNESDAY", "WEDNESDAY", "THURSDAY", "THURSDAY", "THURSDAY", "THURSDAY", "THURSDAY", "THURSDAY", "THURSDAY", "THURSDAY", "THURSDAY", "THURSDAY", "THURSDAY", "THURSDAY", "THURSDAY", "THURSDAY", "THURSDAY", "THURSDAY", "THURSDAY", "THURSDAY", "THURSDAY", "THURSDAY", "THURSDAY", "THURSDAY", "THURSDAY", "THURSDAY", "FRIDAY", "FRIDAY", "FRIDAY", "FRIDAY", "FRIDAY", "FRIDAY", "FRIDAY", "FRIDAY", "FRIDAY", "FRIDAY", "FRIDAY", "FRIDAY", "FRIDAY", "FRIDAY", "FRIDAY", "FRIDAY", "FRIDAY", "FRIDAY", "FRIDAY", "FRIDAY", "FRIDAY", "FRIDAY", "FRIDAY", "FRIDAY", "SATURDAY", "SATURDAY", "SATURDAY", "SATURDAY", "SATURDAY", "SATURDAY", "SATURDAY", "SATURDAY", "SATURDAY", "SATURDAY", "SATURDAY", "SATURDAY", "SATURDAY", "SATURDAY", "SATURDAY", "SATURDAY", "SATURDAY", "SATURDAY", "SATURDAY", "SATURDAY", "SATURDAY", "SATURDAY", "SATURDAY", "SATURDAY", "SUNDAY", "SUNDAY", "SUNDAY", "SUNDAY", "SUNDAY", "SUNDAY", "SUNDAY", "SUNDAY", "SUNDAY", "SUNDAY", "SUNDAY", "SUNDAY", "SUNDAY", "SUNDAY", "SUNDAY", "SUNDAY", "SUNDAY", "SUNDAY", "SUNDAY", "SUNDAY", "SUNDAY", "SUNDAY", "SUNDAY", "SUNDAY", "MONDAY", "MONDAY", "MONDAY", "MONDAY", "MONDAY", "MONDAY", "MONDAY", "MONDAY", "MONDAY", "MONDAY", "MONDAY", "MONDAY", "MONDAY", "MONDAY", "MONDAY", "MONDAY", "MONDAY", "MONDAY", "MONDAY", "MONDAY", "MONDAY", "MONDAY", "MONDAY", "MONDAY"], "y": ["0:00", "1:00", "2:00", "3:00", "4:00", "5:00", "6:00", "7:00", "8:00", "9:00", "10:00", "11:00", "12:00", "13:00", "14:00", "15:00", "16:00", "17:00", "18:00", "19:00", "20:00", "21:00", "22:00", "23:00", "0:00", "1:00", "2:00", "3:00", "4:00", "5:00", "6:00", "7:00", "8:00", "9:00", "10:00", "11:00", "12:00", "13:00", "14:00", "15:00", "16:00", "17:00", "18:00", "19:00", "20:00", "21:00", "22:00", "23:00", "0:00", "1:00", "2:00", "3:00", "4:00", "5:00", "6:00", "7:00", "8:00", "9:00", "10:00", "11:00", "12:00", "13:00", "14:00", "15:00", "16:00", "17:00", "18:00", "19:00", "20:00", "21:00", "22:00", "23:00", "0:00", "1:00", "2:00", "3:00", "4:00", "5:00", "6:00", "7:00", "8:00", "9:00", "10:00", "11:00", "12:00", "13:00", "14:00", "15:00", "16:00", "17:00", "18:00", "19:00", "20:00", "21:00", "22:00", "23:00", "0:00", "1:00", "2:00", "3:00", "4:00", "5:00", "6:00", "7:00", "8:00", "9:00", "10:00", "11:00", "12:00", "13:00", "14:00", "15:00", "16:00", "17:00", "18:00", "19:00", "20:00", "21:00", "22:00", "23:00", "0:00", "1:00", "2:00", "3:00", "4:00", "5:00", "6:00", "7:00", "8:00", "9:00", "10:00", "11:00", "12:00", "13:00", "14:00", "15:00", "16:00", "17:00", "18:00", "19:00", "20:00", "21:00", "22:00", "23:00", "0:00", "1:00", "2:00", "3:00", "4:00", "5:00", "6:00", "7:00", "8:00", "9:00", "10:00", "11:00", "12:00", "13:00", "14:00", "15:00", "16:00", "17:00", "18:00", "19:00", "20:00", "21:00", "22:00", "23:00"], "z": [12.7, 12.7, 12.3, 12.5, 12.7, 12.7, 13.0, 12.7, 12.8, 12.7, 13.2, 14.1, 14.8, 15.3, 15.6, 15.8, 16.0, 15.5, 14.9, 14.4, 13.6, 13.1, 12.3, 11.9, 11.3, 11.1, 10.8, 10.5, 10.4, 10.3, 11.8, 13.7, 14.5, 14.3, 14.9, 16.0, 16.5, 17.0, 17.1, 16.9, 16.4, 15.9, 15.4, 14.4, 13.6, 13.7, 12.8, 12.8, 12.1, 11.9, 11.6, 11.5, 11.2, 12.4, 12.9, 13.7, 14.0, ...

# %% [markdown]
# # 3D Plot

# %%
x = df.numGroups
y = df.maxPlace
z = df.killPlace

trace = go.Scatter3d(x = x, y = y, z = z,
                    mode = 'markers', 
                    marker = dict(size = 12, color = z, opacity = .5))

data = [trace]
layout = go.Layout(margin = dict(l = 0, r = 0, b = 0, t = 0))
fig = go.Figure(data = data, layout = layout)

iplot(fig)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-dc9025e10517> in <module>()
# ----> 1 x = df.numGroups
#       2 y = df.maxPlace
#       3 z = df.killPlace
#       4
#       5 trace = go.Scatter3d(x = x, y = y, z = z,
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'numGroups'

# %% [markdown]
# # Maps

# %%
import shapely
import shapefile
from plotly.figure_factory._county_choropleth import create_choropleth
import geopandas

# %%
mn = pd.read_csv('../input/ex-map/minoritymajority.csv')
mn.head()

# %%
scope = ['New York']
mn_sub = mn[mn.STNAME.isin(scope)]
mn_sub.head()

# %%
values = mn_sub.TOT_POP.tolist()
fips = mn_sub.FIPS.tolist()

# %%
colorscale = ["#171c42","#223f78","#1267b2","#4590c4","#8cb5c9","#b6bed5","#dab2be",
              "#d79d8b","#c46852","#a63329","#701b20","#3c0911"]

# %%
fig = create_choropleth(scope = scope, values = values, fips = fips,
                        round_legend_values = True, 
                        # show_state_data = True,
                        simplify_county = 0,
                        simplify_state = 0,
                        county_outline = {'color': 'rgb(15, 15, 55)', 'width': .5},
                        state_outline = {'width' : .5},
                        legend_title = 'Population Per Country')

# %%
iplot(fig, filename = 'Choropleth Map')
